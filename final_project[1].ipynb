# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
Dataset=pd.read_csv("\\Users\Dr.Salma\Desktop\Summer Camp\Pima Indians Diabetes Binary Classification dataset.csv")

# %%
Dataset.shape
# Out:
# (768, 9)

# %%
Dataset.columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
Dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
Dataset.columns=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
Dataset
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#replace the 0 with mean
mean_bp=Dataset['BloodPressure'].mean()
Dataset['BloodPressure']=Dataset['BloodPressure'].replace(to_replace=0,value=mean_bp)

mean_bmi=Dataset['BMI'].mean()
Dataset['BMI']=Dataset['BMI'].replace(to_replace=0,value=mean_bmi) 

mean_st=Dataset['SkinThickness'].mean()
Dataset['SkinThickness']=Dataset['SkinThickness'].replace(to_replace=0,value=mean_st)

mean_in=Dataset['Insulin'].mean()
Dataset['Insulin']=Dataset['Insulin'].replace(to_replace=0,value=mean_in)

print(mean_bp)
print(mean_bmi)
print(mean_st)
print(mean_in)
# Out:
# 69.10546875
# 31.992578124999998
# 20.536458333333332
# 79.79947916666667

# %%
#column2
Q1_glucose =Dataset['Glucose'].quantile(.25)
Q3_glucose =Dataset['Glucose'].quantile(.75)

mean_glucose =Dataset['Glucose'].mean()

print(mean_glucose )
print(Q1_glucose )
print(Q3_glucose )

Dataset['Glucose']=np.where(Dataset['Glucose']>Q3_glucose ,mean_glucose ,Dataset['Glucose'])
   
Dataset['Glucose']=np.where(Dataset['Glucose']<Q1_glucose ,mean_glucose ,Dataset['Glucose'])
# Out:
# 120.89453125
# 99.0
# 140.25

# %%
#column3
Q1_bp=Dataset['BloodPressure'].quantile(.25)
Q3_bp=Dataset['BloodPressure'].quantile(.75)

print(mean_bp )
print(Q1_bp )
print(Q3_bp )
Dataset['BloodPressure']=np.where(Dataset['BloodPressure']>Q3_bp,
                                             mean_bp,Dataset['BloodPressure'])
   
Dataset['BloodPressure']=np.where(Dataset['BloodPressure']<Q1_bp,
                                             mean_bp,Dataset['BloodPressure'])
# Out:
# 69.10546875
# 64.0
# 80.0

# %%
#column4 
Q1_st=Dataset['SkinThickness'].quantile(.25)
Q3_st=Dataset['SkinThickness'].quantile(.75)


print(mean_st )
print(Q1_st )
print(Q3_st )
Dataset['SkinThickness']=np.where(Dataset['SkinThickness']>Q3_st,
                                             mean_st,Dataset['SkinThickness'])
   
Dataset['SkinThickness']=np.where(Dataset['SkinThickness']<Q1_st,
                                             mean_st,Dataset['SkinThickness'])
# Out:
# 20.536458333333332
# 20.536458333333332
# 32.0

# %%
#column5
Q1_in=Dataset['Insulin'].quantile(.25)
Q3_in=Dataset['Insulin'].quantile(.75)


print(mean_in )
print(Q1_in )
print(Q3_in )
Dataset['Insulin']=np.where(Dataset['Insulin']>Q3_in,
                                             mean_in,Dataset['Insulin'])
   
Dataset['Insulin']=np.where(Dataset['Insulin']<Q1_in,
                                             mean_in,Dataset['Insulin'])
# Out:
# 79.79947916666667
# 79.79947916666667
# 127.25

# %%
#column6
Q1_bmi=Dataset['BMI'].quantile(.25)
Q3_bmi=Dataset['BMI'].quantile(.75)


print(mean_bmi )
print(Q1_bmi)
print(Q3_bmi )
Dataset['BMI']=np.where(Dataset['BMI']>Q3_bmi,
                                             mean_bmi,Dataset['BMI'])
   
Dataset['BMI']=np.where(Dataset['BMI']<Q1_bmi,
                                             mean_bmi,Dataset['BMI'])
# Out:
# 31.992578124999998
# 27.5
# 36.6

# %%
#column7.........not sure i think the value very close (no outliner)
Q1_di=Dataset['DiabetesPedigreeFunction'].quantile(.25)
Q3_di=Dataset['DiabetesPedigreeFunction'].quantile(.75)
mean_di=Dataset['DiabetesPedigreeFunction'].mean()

print(mean_di )
print(Q1_di)
print(Q3_di )
Dataset['DiabetesPedigreeFunction']=np.where(Dataset['DiabetesPedigreeFunction']>Q3_di,
                                             mean_di,Dataset['DiabetesPedigreeFunction'])
   
Dataset['DiabetesPedigreeFunction']=np.where(Dataset['DiabetesPedigreeFunction']<Q1_di,
                                             mean_di,Dataset['DiabetesPedigreeFunction'])
# Out:
# 0.47187630208333325
# 0.24375
# 0.62625

# %%
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


sns.boxplot(x=Dataset['Age'])

# %%
data2= data = Dataset['Age'].values.reshape(-1,1)
fig, ax = plt.subplots()
# plot histogram
ax.hist(data)
# set title and labels
ax.set_title('Age review')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
#columns 7
Q1_age=Dataset['Age'].quantile(.25)
Q3_age=Dataset['Age'].quantile(.75)

mean_age =Dataset['Age'].mean()
print(mean_age )
print(Q1_age)
print(Q3_age )
Dataset['Age']=np.where(Dataset['Age']>Q3_age,
                                             33,Dataset['Age'])
   
Dataset['Age']=np.where(Dataset['Age']<Q1_age,
                                            33,Dataset['Age'])
# Out:
# 33.240885416666664
# 24.0
# 41.0

# %%
Dataset
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              6  120.894531      72.000000      20.536458   79.799479
# 1              1  120.894531      66.000000      29.000000   79.799479
# 2              8  120.894531      64.000000      20.536458   79.799479
# 3              1  120.894531      66.000000      23.000000   94.000000
# 4              0  137.000000      69.105469      20.536458   79.799479
# ..           ...         ...            ...            ...         ...
# 763           10  101.000000      76.000000      20.536458   79.799479
# 764            2  122.000000      70.000000      27.000000   79.799479
# 765            5  121.000000      72.000000      23.000000  112.000000
# 766            1  126.000000      69.105469      20.536458   79.799479
# 767            1  120.894531      70.000000      31.000000   79.799479
#
#            BMI  DiabetesPedigreeFunction  Age  Outcome
# 0    33.600000                  0.471876   33        1
# ...

# %%
#find the outlier (why!!!!!!!!!!!!!!!)
Q1=Dataset.quantile(.25)
Q3=Dataset.quantile(.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Pregnancies                 5.000000
# Glucose                     5.894531
# BloodPressure               2.894531
# SkinThickness               2.463542
# Insulin                     0.000000
# BMI                         0.232422
# DiabetesPedigreeFunction    0.098626
# Age                         5.000000
# Outcome                     1.000000
# dtype: float64

# %%
# visualize Age column

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns


sns.boxplot(x=Dataset['Age'])

# %%
#check the missing values
Dataset.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#label (yes or no)
Dataset_target=Dataset.iloc[ : , 8 ]

Dataset_target=pd.DataFrame(Dataset_target)
Dataset_target
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
#features
Dataset_data=Dataset.iloc[ : , :8 ]

Dataset_data=pd.DataFrame(Dataset_data)
Dataset_data
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 0              6  120.894531      72.000000      20.536458   79.799479
# 1              1  120.894531      66.000000      29.000000   79.799479
# 2              8  120.894531      64.000000      20.536458   79.799479
# 3              1  120.894531      66.000000      23.000000   94.000000
# 4              0  137.000000      69.105469      20.536458   79.799479
# ..           ...         ...            ...            ...         ...
# 763           10  101.000000      76.000000      20.536458   79.799479
# 764            2  122.000000      70.000000      27.000000   79.799479
# 765            5  121.000000      72.000000      23.000000  112.000000
# 766            1  126.000000      69.105469      20.536458   79.799479
# 767            1  120.894531      70.000000      31.000000   79.799479
#
#            BMI  DiabetesPedigreeFunction  Age
# 0    33.600000                  0.471876   33
# ...

# %%
#get the columns' name
col=Dataset_data.columns.values
col
# Out:
# array(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age'], dtype=object)

# %%
#splitting the dataset
x_train,x_test,y_train,y_test= train_test_split(Dataset_data, Dataset_target, test_size= 0.2, random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (614, 8)
# (614, 1)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (154, 8)
# (154, 1)

# %%
x_train.head()#before scalling
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 603            7  120.894531      78.000000      29.000000  126.000000
# 118            4  120.894531      69.105469      23.000000   79.799479
# 247            0  120.894531      69.105469      20.536458   79.799479
# 157            1  109.000000      69.105469      21.000000   79.799479
# 468            8  120.000000      69.105469      20.536458   79.799479
#
#            BMI  DiabetesPedigreeFunction  Age
# 603  35.200000                  0.471876   33
# 118  28.200000                  0.443000   33
# 247  31.992578                  0.427000   33
# 157  31.992578                  0.471876   33
# 468  30.000000                  0.471876   38

# %%
x_test.head()#before scalling
# Out:
#      Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# 661            1  120.894531      76.000000      20.536458   79.799479
# 122            2  107.000000      74.000000      30.000000  100.000000
# 113            4  120.894531      69.105469      20.536458   79.799479
# 14             5  120.894531      72.000000      20.536458   79.799479
# 529            0  111.000000      65.000000      20.536458   79.799479
#
#            BMI  DiabetesPedigreeFunction  Age
# 661  31.992578                  0.471876   33
# 122  33.600000                  0.404000   33
# 113  34.000000                  0.391000   25
# 14   31.992578                  0.587000   33
# 529  31.992578                  0.471876   31

# %%
#scale training data
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()
ScaleMax_1=Scaler.fit(x_train)

x_train=ScaleMax_1.transform(x_train)

x_train=pd.DataFrame(x_train,columns=col)

x_train#after scalling
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.411765  0.534013       0.875000       0.738301  0.978814  0.846154
# 1       0.235294  0.534013       0.319092       0.214902  0.000000  0.076923
# 2       0.000000  0.534013       0.319092       0.000000  0.000000  0.493690
# 3       0.058824  0.243902       0.319092       0.040436  0.000000  0.493690
# 4       0.470588  0.512195       0.319092       0.000000  0.000000  0.274725
# ..           ...       ...            ...            ...       ...       ...
# 609     0.588235  0.048780       0.750000       0.000000  0.000000  0.593407
# 610     0.411765  0.534013       0.125000       0.000000  0.000000  0.318681
# 611     0.235294  0.534013       0.062500       0.127669  0.000000  0.493690
# 612     0.647059  0.534013       0.625000       0.000000  0.000000  0.285714
# 613     0.294118  0.902439       0.319092       0.000000  0.000000  0.493690
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
#scale the testing data
ScaleMax_2=Scaler.fit(x_test)

x_test=ScaleMax_2.transform(x_test)

x_test=pd.DataFrame(x_test,columns=col)

x_test#after scalling
# Out:
#      Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0       0.076923  0.547363       0.750000       0.000000  0.000000  0.499137
# 1       0.153846  0.200000       0.625000       0.825534  0.437236  0.686047
# 2       0.307692  0.547363       0.319092       0.000000  0.000000  0.732558
# 3       0.384615  0.547363       0.500000       0.000000  0.000000  0.499137
# 4       0.000000  0.300000       0.062500       0.000000  0.000000  0.499137
# ..           ...       ...            ...            ...       ...       ...
# 149     0.153846  0.150000       1.000000       0.000000  0.000000  0.697674
# 150     0.307692  0.547363       0.319092       0.127669  0.000000  0.011628
# 151     0.307692  0.547363       0.319092       0.000000  0.000000  0.499137
# 152     0.230769  0.425000       0.625000       0.000000  0.545460  0.499137
# 153     0.076923  0.200000       0.500000       0.825534  0.047630  0.360465
#
#      DiabetesPedigreeFunction       Age
# ...

# %%
#Normalize dataset
from sklearn.preprocessing import Normalizer

normalizer = Normalizer()

#Normalize the training data
fit_training_data =normalizer.fit(x_train)

x_train=fit_training_data.transform(x_train)

x_train =  pd.DataFrame(x_train,columns=col)

x_train.head()#after normalization
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.203870  0.264396       0.433223       0.365541  0.484622  0.418941
# 1     0.229736  0.521398       0.311554       0.209826  0.000000  0.075106
# 2     0.000000  0.499511       0.298476       0.000000  0.000000  0.461793
# 3     0.057405  0.238022       0.311399       0.039461  0.000000  0.481788
# 4     0.361041  0.392963       0.244811       0.000000  0.000000  0.210773
#
#    DiabetesPedigreeFunction       Age
# 0                  0.296906  0.262118
# 1                  0.511313  0.516905
# 2                  0.450465  0.495207
# 3                  0.585217  0.516648
# 4                  0.460078  0.631823

# %%
#Normalize the testing data
fit_testing_data =normalizer.fit(x_test)

x_test=fit_testing_data.transform(x_test)

x_test =  pd.DataFrame(x_test,columns=col)

x_test.head()#after normalization
# Out:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.058115  0.413528       0.566618       0.000000  0.000000  0.377093
# 1     0.102517  0.133272       0.416475       0.550103  0.291357  0.457154
# 2     0.282889  0.503240       0.293369       0.000000  0.000000  0.673506
# 3     0.269767  0.383918       0.350698       0.000000  0.000000  0.350092
# 4     0.000000  0.322155       0.067116       0.000000  0.000000  0.535999
#
#    DiabetesPedigreeFunction       Age
# 0                  0.449877  0.399966
# 1                  0.278087  0.352779
# 2                  0.352312  0.054082
# 3                  0.629599  0.371327
# 4                  0.639452  0.442174

# %%
data2= data = x_test['Age'].values.reshape(-1,1)
fig, ax = plt.subplots()
# plot histogram
ax.hist(data)
# set title and labels
ax.set_title('Age review')
ax.set_xlabel('X')
ax.set_ylabel('Y')
# Out:
# Text(0, 0.5, 'Y')

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
import xgboost
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier

from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB

from sklearn.model_selection import cross_val_score

# %%
classifiers=[]
model1 = xgboost.XGBClassifier()
classifiers.append(model1)
model2 = svm.SVC()
classifiers.append(model2)
model3 = tree.DecisionTreeClassifier()
classifiers.append(model3)
model4 = RandomForestClassifier()
classifiers.append(model4)

# %%
model5 = svm.SVC(gamma='auto', C=1)
classifiers.append(model5)
#####
model6 = GaussianProcessClassifier(1.0 * RBF(1.0))
classifiers.append(model6)
##
model7 = DecisionTreeClassifier(max_depth=5)
classifiers.append(model7)
##
model8 = KNeighborsClassifier(n_neighbors=5)
classifiers.append(model8)

# %%
model9 =RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1) 
classifiers.append(model9)
##
model10 =MLPClassifier(alpha=1, max_iter=1000)
classifiers.append(model10)
##
model11 =AdaBoostClassifier()
classifiers.append(model11)
##
model12 =GaussianNB()
classifiers.append(model12)

# %%
for clf in classifiers:
 
    a=cross_val_score(clf,x_train,y_train,cv=5,scoring='accuracy').mean()
    
    print("Accuracy of %s is %s"%(clf, a))
    print("................................")
# Out:
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py:219: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\preprocessing\label.py:252: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy of XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
# ...

# %%
#choose GaussianProcessClassifier algorithm 
final_model= GaussianProcessClassifier(1.0 * RBF(1.0)).fit(x_train, y_train)

y_pred= final_model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

print("Accuracy of diabetes prediction test is %s"%(acc))
# Out:
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Accuracy of diabetes prediction test is 0.7207792207792207

# %%
import pandas 
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import RandomForestClassifier,  AdaBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
# load dataset
#url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
dataframe = pd.DataFrame(x_train)
array = dataframe.values
X = array[:,:]
dataframe_L = pd.DataFrame(y_train)
array_L= dataframe_L.values
Y = array_L[:,0]

# prepare configuration for cross validation test harness
seed = 7
# prepare models
models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier(3)))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))
models.append(('RandF', RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1)))
models.append(('AdaB',  AdaBoostClassifier()))
models.append(('MLP',  MLPClassifier()))
models.append(('GPC',  GaussianProcessClassifier(1.0 * RBF(1.0))))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# LR: 0.630354 (0.067155)
# LDA: 0.648255 (0.056402)
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# c:\users\dr.salma\appdata\local\programs\python\python37\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# ...
