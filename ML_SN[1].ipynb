# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
Dataset=pd.read_csv("\\Users\Dr.Salma\Desktop\Summer Camp\Pima Indians Diabetes Binary Classification dataset.csv")

# %%
Dataset.shape
# Out:
# (768, 9)

# %%
Dataset
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
#find the outlier
Q1=Dataset.quantile(.25)
Q3=Dataset.quantile(.75)
IQR=Q3-Q1
print(IQR)
# Out:
# Number of times pregnant                                                      5.0000
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test     41.2500
# Diastolic blood pressure (mm Hg)                                             18.0000
# Triceps skin fold thickness (mm)                                             32.0000
# 2-Hour serum insulin (mu U/ml)                                              127.2500
# Body mass index (weight in kg/(height in m)^2)                                9.3000
# Diabetes pedigree function                                                    0.3825
# Age (years)                                                                  17.0000
# Class variable (0 or 1)                                                       1.0000
# dtype: float64

# %%
#fix it
Dataset=Dataset[~((Dataset<(Q1-1.5*IQR))| (Dataset>(Q3+1.5*IQR))).any(axis=1)]

# %%
Dataset.shape
# Out:
# (639, 9)

# %%
#check the missing values
Dataset.isnull().sum()
# Out:
# Number of times pregnant                                                    0
# Plasma glucose concentration a 2 hours in an oral glucose tolerance test    0
# Diastolic blood pressure (mm Hg)                                            0
# Triceps skin fold thickness (mm)                                            0
# 2-Hour serum insulin (mu U/ml)                                              0
# Body mass index (weight in kg/(height in m)^2)                              0
# Diabetes pedigree function                                                  0
# Age (years)                                                                 0
# Class variable (0 or 1)                                                     0
# dtype: int64

# %%
#label (yes or no)
Dataset_target=Dataset.iloc[ : , 8 ]
print(Dataset_target)
#Dataset_target=pd.DataFrame(Dataset_target)
#Dataset_target
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Class variable (0 or 1), Length: 639, dtype: int64

# %%
#features
Dataset_data=Dataset.iloc[ : , :8 ]
print(Dataset_data)
#Dataset_data=pd.DataFrame(Dataset_data)
#Dataset_data
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 5                           5
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 5                                                  116
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
col=Dataset_data.columns.values
col
# Out:
# array(['Number of times pregnant',
#        'Plasma glucose concentration a 2 hours in an oral glucose tolerance test',
#        'Diastolic blood pressure (mm Hg)',
#        'Triceps skin fold thickness (mm)',
#        '2-Hour serum insulin (mu U/ml)',
#        'Body mass index (weight in kg/(height in m)^2)',
#        'Diabetes pedigree function', 'Age (years)'], dtype=object)

# %%
# scaling 

#scale training data
from sklearn.preprocessing import MinMaxScaler
Scaler=MinMaxScaler()

# %%
Scaler.fit(Dataset_data)
Dataset_data = ScaleMax_1.transform(Dataset_data)

# %%
df_dataset = pd.DataFrame(Dataset_data, columns = col)
df_dataset
# Out:
#      Number of times pregnant  \
# 0                    0.461538
# 1                    0.076923
# 2                    0.615385
# 3                    0.076923
# 4                    0.384615
# ..                        ...
# 634                  0.769231
# 635                  0.153846
# 636                  0.384615
# 637                  0.076923
# 638                  0.076923
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                             0.675325
# 1                                             0.266234
# 2                                             0.902597
# 3                                             0.292208
# 4                                             0.467532
# ..                                                 ...
# 634                                           0.370130
# 635                                           0.506494
# 636                                           0.500000
# ...

# %%
#Normalize dataset
from sklearn.preprocessing import Normalizer

# %%
normalizer = Normalizer()
#Normalize the training data
fit_training_data =normalizer.fit(Dataset_data)
Dataset_data=fit_training_data.transform(Dataset_data)
Normalized_Dataset =  pd.DataFrame(Dataset_data,columns=col)
Normalized_Dataset
# Out:
#      Number of times pregnant  \
# 0                    0.314584
# 1                    0.094737
# 2                    0.470613
# 3                    0.099432
# 4                    0.443184
# ..                        ...
# 634                  0.437375
# 635                  0.145406
# 636                  0.376293
# 637                  0.079883
# 638                  0.086542
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                             0.460300
# 1                                             0.327890
# 2                                             0.690259
# 3                                             0.377714
# 4                                             0.538727
# ..                                                 ...
# 634                                           0.210451
# 635                                           0.478706
# 636                                           0.489181
# ...

# %%
x_train,x_test,y_train,y_test= train_test_split(Dataset_data, Dataset_target, test_size= 0.2, random_state=0)

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (511, 8)
# (511,)

# %%
print(x_test.shape)
print(y_test.shape)
# Out:
# (128, 8)
# (128,)

# %%
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn import tree

# %%
svm_clf = svm.SVC(kernel='linear', C=1 ,gamma=0.2, random_state=1)
cross_val_score(svm_clf,x_train, y_train ,cv=10,scoring = 'accuracy' ).mean()
# Out:
# 0.6967420814479638

# %%
knn = KNeighborsClassifier( n_neighbors=7,algorithm='auto',weights='distance')
cross_val_score(knn,x_train, y_train ,cv=10,scoring = 'accuracy' ).mean()
# Out:
# 0.7005128205128204

# %%
R_clf = RandomForestClassifier(n_estimators = 10,random_state=1)
cross_val_score(R_clf,x_train, y_train ,cv=10,scoring = 'accuracy' ).mean()
# Out:
# 0.7120859728506788

# %%
dtc = tree.DecisionTreeClassifier( random_state = 0, max_depth=5)
cross_val_score(dtc,x_train, y_train ,cv=10,scoring = 'accuracy' ).mean()
# Out:
# 0.6630904977375566

# %%
import pandas as pd 
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm, tree
import xgboost
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import cross_val_score
#data  =  pd.read_csv("D://Blogs//Iris Multiple Algo//Iris.csv")
#Create Dependent and Independent Datasets based on our Dependent #and Independent features
#X  = data[['SepalLengthCm','SepalWidthCm','PetalLengthCm']]
#y= data['Species']
#Split the Data into Training and Testing sets with test size as #30%
#X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, shuffle=True)

#//////////////////////////////////
classifiers=[]
model1 = xgboost.XGBClassifier()
classifiers.append(model1)
#....
model2 = svm.SVC()
classifiers.append(model2)
#....
model3 = tree.DecisionTreeClassifier()
classifiers.append(model3)
#....
model4 = RandomForestClassifier(n_estimators = 10,random_state=1)
classifiers.append(model4)
#....
model5 = KNeighborsClassifier(n_neighbors=7,algorithm='auto',weights='distance')
classifiers.append(model5)
#....
model6 = GaussianProcessClassifier(1.0 * RBF(1.0),random_state=0)
classifiers.append(model6)
##
model7 = DecisionTreeClassifier(max_depth=5)
classifiers.append(model7)
##
model8 = KNeighborsClassifier(n_neighbors=5)
classifiers.append(model8)
#.....
model9 =RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1) 
classifiers.append(model9)
##
model10 =MLPClassifier(alpha=1, max_iter=1000)
classifiers.append(model10)
##
model11 =AdaBoostClassifier(random_state=2)
classifiers.append(model11)
##
model12 =GaussianNB()
classifiers.append(model12)

#/////////////////////////////////

for clf in classifiers:
    a = cross_val_score(clf,x_train, y_train ,cv=10,scoring = 'accuracy' ).mean()
    #clf.fit(X_train, y_train)
    #y_pred= clf.predict(X_test)
    #acc = accuracy_score(y_test, y_pred)
    print("Accuracy of %s is %s"%(clf, a))
    print('........................................................')
    #cm = confusion_matrix(y_test, y_pred)
    #print("Confusion Matrix of %s is %s"%(clf, cm)
# Out:
# Accuracy of XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0,
#               learning_rate=0.1, max_delta_step=0, max_depth=3,
#               min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#               nthread=None, objective='binary:logistic', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#               silent=None, subsample=1, verbosity=1) is 0.7065505279034691
# ........................................................
# Accuracy of SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='rbf', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False) is 0.6967420814479638
# ........................................................
# ...

# %%
#choose GaussianProcessClassifier algorithm 
final_model= GaussianProcessClassifier(1.0 * RBF(1.0)).fit(x_train, y_train)

y_pred= final_model.predict(x_test)
acc = accuracy_score(y_test, y_pred)

print("Accuracy of diabetes prediction test is %s"%(acc))
